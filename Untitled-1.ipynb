# %%
firstCharacter = 'a' # 1 byte
name = "Muhammad" # character * bytes
number1 = 256
number2 = 15.5
number3 = -335

# %%
emptystr = ""

# %%
print(type(emptystr))
# Out:
# <class 'str'>

# %%
numberArr = [number1, number2, number3]

Fruits  = ["apple", "banana", "cherry"]

# %%
count = 0

for x in Fruits:
    # internal block
    print(count)
    count= count + 1
    print(x)
# Out:
# 0
# apple
# 1
# banana
# 2
# cherry

# %%
for x in range(0,10,4):
    print(x)
# Out:
# 0
# 4
# 8

# %%
print(fullname)
# Out:
# Muhammad Ali Alam

# %%
for x in fullname:
    print(x)
# Out:
# M
# u
# h
# a
# m
# m
# a
# d
#
# A
# l
# i
#
# A
# l
# a
# m

# %%
print(numberArr)
# Out:
# [256, 15.5, -335]

# %%
print(Fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
UserAge = -20

# %%
if UserAge > 17:
    print("your age is correct")
elif UserAge < 0:
    print("Entered age is invalid")
else:
    print("Under Aged")
# Out:
# Entered age is invalid

# %%
for():

# %%
boolVar = number1 < number2

# %%
print(boolVar)
# Out:
# False

# %%
print(number2)
# Out:
# 15.5

# %%
print(f"All significant digits: {number2:.17g}")
# Out:
# All significant digits: 15.5

# %%
fullname = name + " " + "Ali" + " " + "Alam"

# %%
print(fullname)
# Out:
# Muhammad Ali Alam

# %%
print()

# %%
print(type(firstCharacter))
print(type(name))
print(type(number1))
print(type(number2))
print(type(number3))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
